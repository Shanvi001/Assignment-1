# %%
import pandas as pd

# %%
df = pd.read_csv("Traffic_Crashes.csv")
#df = pd.read_csv("Traffic_Crashes_-_Crashes(2).csv")

# %%
df.head()
# Out:
#                                      CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...              NaN
# 1  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...              NaN
# 2  61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c...              NaN
# 3  004cd14d0303a9163aad69a2d7f341b7da2a8572b2ab33...              NaN
# 4  a1d5f0ea90897745365a4cbb06cc60329a120d89753fac...              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  08/18/2023 12:50:00 PM                  15                  OTHER
# 1  07/29/2023 02:45:00 PM                  30         TRAFFIC SIGNAL
# 2  08/18/2023 05:58:00 PM                  30            NO CONTROLS
# 3  11/26/2019 08:38:00 AM                  25            NO CONTROLS
# 4  08/18/2023 10:45:00 AM                  20            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION LIGHTING_CONDITION  \
# 0  FUNCTIONING PROPERLY             CLEAR           DAYLIGHT
# ...

# %%
df.tail()
# Out:
#                                           CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 919069  fb93c3183712074555fc2062c807c10dc6e25be439705b...              NaN
# 919070  ddb7c68c829fa774fa13b1a8bda817c7f9094a66044723...              NaN
# 919071  7ec8a53416079fa3a79b03b3530e4e42e5fde5d9d95959...              NaN
# 919072  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b...              NaN
# 919073  37b7acd5f2db6728ca4ac0d7e4217f78b6703f769754b4...              NaN
#
#                     CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 919069  05/28/2020 12:12:00 AM                  30      STOP SIGN/FLASHER
# 919070        07-12-2020 18:45                  20            NO CONTROLS
# 919071  12/26/2018 11:45:00 AM                  20            NO CONTROLS
# 919072        01-06-2020 08:30                  15            NO CONTROLS
# 919073  05/31/2023 05:00:00 PM                  15                UNKNOWN
#
# ...

# %%
df.isna()
# Out:
#         CRASH_RECORD_ID  CRASH_DATE_EST_I  CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0                 False              True       False               False
# 1                 False              True       False               False
# 2                 False              True       False               False
# 3                 False              True       False               False
# 4                 False              True       False               False
# ...                 ...               ...         ...                 ...
# 919069            False              True       False               False
# 919070            False              True       False               False
# 919071            False              True       False               False
# 919072            False              True       False               False
# 919073            False              True       False               False
#
#         TRAFFIC_CONTROL_DEVICE  DEVICE_CONDITION  WEATHER_CONDITION  \
# ...

# %%
df = df.drop(columns=['CRASH_DATE_EST_I', 'LANE_CNT', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I'])
df.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  08/18/2023 12:50:00 PM
# 1  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  07/29/2023 02:45:00 PM
# 2  61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c...  08/18/2023 05:58:00 PM
# 3  004cd14d0303a9163aad69a2d7f341b7da2a8572b2ab33...  11/26/2019 08:38:00 AM
# 4  a1d5f0ea90897745365a4cbb06cc60329a120d89753fac...  08/18/2023 10:45:00 AM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# 0                  15                  OTHER  FUNCTIONING PROPERLY
# 1                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2                  30            NO CONTROLS           NO CONTROLS
# 3                  25            NO CONTROLS           NO CONTROLS
# 4                  20            NO CONTROLS           NO CONTROLS
#
#   WEATHER_CONDITION LIGHTING_CONDITION      FIRST_CRASH_TYPE  \
# ...

# %%
df1 = df.fillna(0)
df1.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  08/18/2023 12:50:00 PM
# 1  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  07/29/2023 02:45:00 PM
# 2  61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c...  08/18/2023 05:58:00 PM
# 3  004cd14d0303a9163aad69a2d7f341b7da2a8572b2ab33...  11/26/2019 08:38:00 AM
# 4  a1d5f0ea90897745365a4cbb06cc60329a120d89753fac...  08/18/2023 10:45:00 AM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# 0                  15                  OTHER  FUNCTIONING PROPERLY
# 1                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2                  30            NO CONTROLS           NO CONTROLS
# 3                  25            NO CONTROLS           NO CONTROLS
# 4                  20            NO CONTROLS           NO CONTROLS
#
#   WEATHER_CONDITION LIGHTING_CONDITION      FIRST_CRASH_TYPE  \
# ...

# %%
df.HIT_AND_RUN_I
# Out:
# 0         NaN
# 1           Y
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 919069      Y
# 919070      Y
# 919071    NaN
# 919072    NaN
# 919073      N
# Name: HIT_AND_RUN_I, Length: 919074, dtype: object

# %%
df['HIT_AND_RUN_I'] = df['HIT_AND_RUN_I'].fillna("X")

# %%
df.HIT_AND_RUN_I
# Out:
# 0         X
# 1         Y
# 2         X
# 3         X
# 4         X
#          ..
# 919069    Y
# 919070    Y
# 919071    X
# 919072    X
# 919073    N
# Name: HIT_AND_RUN_I, Length: 919074, dtype: object

# %%
rows_with_nan = df.isna().any(axis=1).sum()
print(rows_with_nan)
# Out:
# 37479

# %%
df = df.dropna()

# %%
rows_with_nan = df.isna().any(axis=1).sum()
print(rows_with_nan)
# Out:
# 0

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [CRASH_RECORD_ID, CRASH_DATE, POSTED_SPEED_LIMIT, TRAFFIC_CONTROL_DEVICE, DEVICE_CONDITION, WEATHER_CONDITION, LIGHTING_CONDITION, FIRST_CRASH_TYPE, TRAFFICWAY_TYPE, ALIGNMENT, ROADWAY_SURFACE_COND, ROAD_DEFECT, REPORT_TYPE, CRASH_TYPE, HIT_AND_RUN_I, DAMAGE, DATE_POLICE_NOTIFIED, PRIM_CONTRIBUTORY_CAUSE, SEC_CONTRIBUTORY_CAUSE, STREET_NO, STREET_DIRECTION, STREET_NAME, BEAT_OF_OCCURRENCE, NUM_UNITS, MOST_SEVERE_INJURY, INJURIES_TOTAL, INJURIES_FATAL, INJURIES_INCAPACITATING, INJURIES_NON_INCAPACITATING, INJURIES_REPORTED_NOT_EVIDENT, INJURIES_NO_INDICATION, INJURIES_UNKNOWN, CRASH_HOUR, CRASH_DAY_OF_WEEK, CRASH_MONTH, LATITUDE, LONGITUDE, LOCATION]
# Index: []
#
# [0 rows x 38 columns]

# %%
df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32312\3047994292.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'])

# %%
df['Crash Date'] = df['CRASH_DATE'].dt.date
df['Crash Time'] = df['CRASH_DATE'].dt.time
df
# Out:
#                                           CRASH_RECORD_ID          CRASH_DATE  \
# 1       5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 2       61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c... 2023-08-18 17:58:00
# 13      fd05285e9d273fe20cbbebf84794045828a2ba589073b6... 2023-07-29 14:30:00
# 20      161ff459c7fff8e1359204d1c54db502674fdfbf7036a9... 2023-09-20 12:57:00
# 23      1ee2180a89cc02c0b756f95b5b2755bb5cc9d93450f5ca... 2023-08-09 19:55:00
# ...                                                   ...                 ...
# 919043  6bd73dc0b10ee0272e9269bec32b57327611c2ad3cf19b... 2021-11-05 22:56:00
# 919069  fb93c3183712074555fc2062c807c10dc6e25be439705b... 2020-05-28 00:12:00
# 919071  7ec8a53416079fa3a79b03b3530e4e42e5fde5d9d95959... 2018-12-26 11:45:00
# 919072  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b... 2020-01-06 08:30:00
# 919073  37b7acd5f2db6728ca4ac0d7e4217f78b6703f769754b4... 2023-05-31 17:00:00
#
# ...

# %%
df['DATE_POLICE_NOTIFIED'] = pd.to_datetime(df['DATE_POLICE_NOTIFIED'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_32312\451310334.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATE_POLICE_NOTIFIED'] = pd.to_datetime(df['DATE_POLICE_NOTIFIED'])

# %%
df['Police Date'] = df['DATE_POLICE_NOTIFIED'].dt.date
df['Police Time'] = df['DATE_POLICE_NOTIFIED'].dt.time
df
# Out:
#                                           CRASH_RECORD_ID          CRASH_DATE  \
# 1       5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 2       61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c... 2023-08-18 17:58:00
# 13      fd05285e9d273fe20cbbebf84794045828a2ba589073b6... 2023-07-29 14:30:00
# 20      161ff459c7fff8e1359204d1c54db502674fdfbf7036a9... 2023-09-20 12:57:00
# 23      1ee2180a89cc02c0b756f95b5b2755bb5cc9d93450f5ca... 2023-08-09 19:55:00
# ...                                                   ...                 ...
# 919043  6bd73dc0b10ee0272e9269bec32b57327611c2ad3cf19b... 2021-11-05 22:56:00
# 919069  fb93c3183712074555fc2062c807c10dc6e25be439705b... 2020-05-28 00:12:00
# 919071  7ec8a53416079fa3a79b03b3530e4e42e5fde5d9d95959... 2018-12-26 11:45:00
# 919072  f829a8bd9a1afc120ed6720cdb20a22b1a90b81278002b... 2020-01-06 08:30:00
# 919073  37b7acd5f2db6728ca4ac0d7e4217f78b6703f769754b4... 2023-05-31 17:00:00
#
# ...

# %%
unique_values = df['POSTED_SPEED_LIMIT'].unique()
print(unique_values)
sorted_unique_values = sorted(unique_values)
sorted_unique_values
# Out:
# [30 10 15 20 35 25  5 45 40 50  0  3 55  9 60 39 18 99 65  1 26  2 24 34
#   6 14 23 22 11 32 12 70 33  7 36 49  8 63 29 38 44 62  4 16 31 46]
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(18),
#  np.int64(20),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(44),
#  np.int64(45),
#  np.int64(46),
#  np.int64(49),
#  np.int64(50),
#  np.int64(55),
#  np.int64(60),
#  np.int64(62),
#  np.int64(63),
#  np.int64(65),
#  np.int64(70),
#  np.int64(99)]

# %%
df = df.drop(columns=['CRASH_DATE', 'DATE_POLICE_NOTIFIED'])
df.head()
# Out:
#                                       CRASH_RECORD_ID  POSTED_SPEED_LIMIT  \
# 1   5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...                  30
# 2   61fcb8c1eb522a6469b460e2134df3d15f82e81fd93e9c...                  30
# 13  fd05285e9d273fe20cbbebf84794045828a2ba589073b6...                  10
# 20  161ff459c7fff8e1359204d1c54db502674fdfbf7036a9...                  15
# 23  1ee2180a89cc02c0b756f95b5b2755bb5cc9d93450f5ca...                  30
#
#    TRAFFIC_CONTROL_DEVICE        DEVICE_CONDITION WEATHER_CONDITION  \
# 1          TRAFFIC SIGNAL    FUNCTIONING PROPERLY             CLEAR
# 2             NO CONTROLS             NO CONTROLS             CLEAR
# 13            NO CONTROLS             NO CONTROLS           UNKNOWN
# 20            NO CONTROLS             NO CONTROLS             CLEAR
# 23         TRAFFIC SIGNAL  FUNCTIONING IMPROPERLY             CLEAR
#
#    LIGHTING_CONDITION      FIRST_CRASH_TYPE                  TRAFFICWAY_TYPE  \
# ...

# %%
df.to_csv("clean_chicago_traffic.csv", index=False)
